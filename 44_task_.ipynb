# %% [markdown]
# <a href="https://colab.research.google.com/github/Saturnaliya/05dz_Python/blob/main/44_task_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задача 44 #

# %% [markdown]
#  ## В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies? ##

# %% [markdown]
# import random
# lst = ['robot'] * 10
# lst += ['human'] * 10
# random.shuffle(lst)
# data = pd.DataFrame({'whoAmI':lst})
# data.head()

# %%
import pandas as pd

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  robot
# 3  robot
# 4  human

# %%
def rule(x, y):
  if x == 'human' and y == 'robot':
     return 1
  else:
     return 0
  if x == 'robot' and y == 'human':
     return 1
  else:
     return 0

df = pd.DataFrame({ 'WhoAmI':[ 'human' ,'human', 'robot', 'robot', 'robot'], 'human': [1, 1, 0, 0, 0]})
df['robot'] = df.apply(lambda x: rule(x['WhoAmI'], x['human']), axis = 1)
df.head()
# Out:
#   WhoAmI  human  robot
# 0  human      1      0
# 1  human      1      0
# 2  robot      0      0
# 3  robot      0      0
# 4  robot      0      0
